# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cluster_df = pd.read_csv(r'C:\Users\zr_1\final_project\Clustering\clustering_v2.csv')
cluster_df
## Analazying cluster 0
# Out:
#        sembrada  cosechada  siniestrada  volumenproduccion    latitud  \
# 0      35012.00   35012.00          0.0          401061.32  24.767219
# 1       1302.00    1302.00          0.0          108818.40  31.808944
# 2      30597.34   30597.34          0.0          361643.68  25.783417
# 3      30816.00   30816.00          0.0          364810.83  24.808808
# 4       2331.00    2331.00          0.0          232416.02  24.808808
# ...         ...        ...          ...                ...        ...
# 11247     11.00       0.00         11.0               0.00  24.048799
# 11248     10.00       0.00         10.0               0.00  23.301759
# 11249   1415.00       0.00       1415.0               0.00  19.638472
# 11250   1210.00       0.00       1210.0               0.00  19.664859
# 11251      0.50       0.00          0.5               0.00  21.567599
#
#          longitud  altitud  cicloproductivo_Otoño-Invierno  \
# 0     -107.696760     12.0                               1
# ...

# %%
cluster_0 = cluster_df[cluster_df['K=8 Cluster Labels'] == 0]
cluster_0
# Out:
#        sembrada  cosechada  siniestrada  volumenproduccion    latitud  \
# 224     20000.0    20000.0          0.0          290000.00  28.406312
# 225     19430.0    19430.0          0.0          221502.00  28.406312
# 255      4657.0     4657.0          0.0          201112.75  25.570107
# 272     11770.0    11770.0          0.0          182505.62  25.039080
# 303     13960.0    13960.0          0.0          184272.00  22.771900
# ...         ...        ...          ...                ...        ...
# 11238       7.0        0.0          7.0               0.00  30.713339
# 11239       1.0        0.0          1.0               0.00  30.742054
# 11240      10.0        0.0         10.0               0.00  31.102665
# 11241     102.0        0.0        102.0               0.00  30.884909
# 11248      10.0        0.0         10.0               0.00  23.301759
#
#          longitud  altitud  cicloproductivo_Otoño-Invierno  \
# 224   -106.866044   2062.0                               0
# ...

# %%
plt.figure(figsize=(10, 7))
sns.set(style = 'whitegrid')  
sns.stripplot(x="rendimiento", y="estado", jitter=0.05, data=cluster_0)

# %%
cluster_0.groupby(['K=8 Cluster Labels'])['cultivo_Avena forrajera en verde','cultivo_Frijol',
                              'cultivo_Maíz grano','cultivo_Pastos y praderas',
                              'cultivo_Tomate rojo (jitomate)'].mean()
# Out:
# <ipython-input-9-8c33b1b40a8d>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   cluster_0.groupby(['K=8 Cluster Labels'])['cultivo_Avena forrajera en verde','cultivo_Frijol',
#                     cultivo_Avena forrajera en verde  cultivo_Frijol  \
# K=8 Cluster Labels
# 0                                                  1               0
#
#                     cultivo_Maíz grano  cultivo_Pastos y praderas  \
# K=8 Cluster Labels
# 0                                    0                          0
#
#                     cultivo_Tomate rojo (jitomate)
# K=8 Cluster Labels
# 0                                                0

# %%
## Avena forrajera en verde is the top crop for cluster 0

# %%
cluster0_cultivo=pd.DataFrame(cluster_0.groupby(['estado'])['cultivo_Avena forrajera en verde'].sum())
cluster0_cultivo
# Out:
#                  cultivo_Avena forrajera en verde
# estado
# Aguascalientes                                 21
# Baja California                                11
# Chihuahua                                      92
# Coahuila                                       64
# Durango                                        82
# Guanajuato                                     46
# Guerrero                                        2
# Hidalgo                                       102
# Jalisco                                        99
# Michoacán                                     152
# Morelos                                         6
# México                                        186
# Nuevo León                                     26
# Oaxaca                                         37
# Puebla                                        104
# Querétaro                                      16
# San Luis Potosí                                70
# Sonora                                         70
# ...

# %%
## Mexico is the state that produces the most Avena forrajera en verde
