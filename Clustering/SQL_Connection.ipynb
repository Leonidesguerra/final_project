# %%
import pandas as pd

# %%
df = pd.read_csv('clustering_v2.csv')

# %%
df
# Out:
#        sembrada  cosechada  siniestrada  volumenproduccion    latitud  \
# 0      35012.00   35012.00          0.0          401061.32  24.767219
# 1       1302.00    1302.00          0.0          108818.40  31.808944
# 2      30597.34   30597.34          0.0          361643.68  25.783417
# 3      30816.00   30816.00          0.0          364810.83  24.808808
# 4       2331.00    2331.00          0.0          232416.02  24.808808
# ...         ...        ...          ...                ...        ...
# 11247     11.00       0.00         11.0               0.00  24.048799
# 11248     10.00       0.00         10.0               0.00  23.301759
# 11249   1415.00       0.00       1415.0               0.00  19.638472
# 11250   1210.00       0.00       1210.0               0.00  19.664859
# 11251      0.50       0.00          0.5               0.00  21.567599
#
#          longitud  altitud  cicloproductivo_Otoño-Invierno  \
# 0     -107.696760     12.0                               1
# 1     -116.595134     18.0                               0
# 2     -108.994343      9.0                               1
# 3     -107.393756     57.0                               1
# 4     -107.393756     57.0                               1
# ...           ...      ...                             ...
# 11247  -98.900294    149.0                               0
# 11248  -99.547539   1263.0                               1
# 11249  -97.103496   2420.0                               0
# 11250  -97.001371   1746.0                               0
# 11251  -88.232063     12.0                               1
#
#        cicloproductivo_Perennes  cicloproductivo_Primavera-Verano  ...  \
# 0                             0                                 0  ...
# 1                             0                                 1  ...
# 2                             0                                 0  ...
# 3                             0                                 0  ...
# 4                             0                                 0  ...
# ...                         ...                               ...  ...
# 11247                         0                                 1  ...
# 11248                         0                                 0  ...
# 11249                         0                                 1  ...
# 11250                         0                                 1  ...
# 11251                         0                                 0  ...
#
#        modalidad_Temporal  cultivo_Avena forrajera en verde  cultivo_Frijol  \
# 0                       0                                 0               0
# 1                       0                                 0               0
# 2                       0                                 0               0
# 3                       0                                 0               0
# 4                       0                                 0               0
# ...                   ...                               ...             ...
# 11247                   0                                 0               0
# 11248                   1                                 1               0
# 11249                   1                                 0               0
# 11250                   1                                 0               0
# 11251                   0                                 0               0
#
#        cultivo_Maíz grano  cultivo_Pastos y praderas  \
# 0                       1                          0
# 1                       0                          0
# 2                       1                          0
# 3                       1                          0
# 4                       0                          0
# ...                   ...                        ...
# 11247                   0                          0
# 11248                   0                          0
# 11249                   1                          0
# 11250                   1                          0
# 11251                   0                          0
#
#        cultivo_Tomate rojo (jitomate)  K=8 Cluster Labels  rendimiento  \
# 0                                   0                   7        11.45
# 1                                   1                   4        83.58
# 2                                   0                   7        11.82
# 3                                   0                   7        11.84
# 4                                   1                   4        99.71
# ...                               ...                 ...          ...
# 11247                               1                   4         0.00
# 11248                               0                   0         0.00
# 11249                               0                   6         0.00
# 11250                               0                   6         0.00
# 11251                               1                   4         0.00
#
#                         cultivo           estado
# 0                    Maíz grano          Sinaloa
# 1        Tomate rojo (jitomate)  Baja California
# 2                    Maíz grano          Sinaloa
# 3                    Maíz grano          Sinaloa
# 4        Tomate rojo (jitomate)          Sinaloa
# ...                         ...              ...
# 11247    Tomate rojo (jitomate)       Tamaulipas
# 11248  Avena forrajera en verde       Tamaulipas
# 11249                Maíz grano         Veracruz
# 11250                Maíz grano         Veracruz
# 11251    Tomate rojo (jitomate)          Yucatán
#
# [11252 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['sembrada', 'cosechada', 'siniestrada', 'volumenproduccion', 'latitud',
#        'longitud', 'altitud', 'cicloproductivo_Otoño-Invierno',
#        'cicloproductivo_Perennes', 'cicloproductivo_Primavera-Verano',
#        'modalidad_Riego', 'modalidad_Temporal',
#        'cultivo_Avena forrajera en verde', 'cultivo_Frijol',
#        'cultivo_Maíz grano', 'cultivo_Pastos y praderas',
#        'cultivo_Tomate rojo (jitomate)', 'K=8 Cluster Labels', 'rendimiento',
#        'cultivo', 'estado'],
#       dtype='object')

# %%
df.rename(columns = {"cultivo_Tomate rojo (jitomate)":"cultivo_Tomate rojo"}, inplace=True)

# %%
df
# Out:
#        sembrada  cosechada  siniestrada  volumenproduccion    latitud  \
# 0      35012.00   35012.00          0.0          401061.32  24.767219
# 1       1302.00    1302.00          0.0          108818.40  31.808944
# 2      30597.34   30597.34          0.0          361643.68  25.783417
# 3      30816.00   30816.00          0.0          364810.83  24.808808
# 4       2331.00    2331.00          0.0          232416.02  24.808808
# ...         ...        ...          ...                ...        ...
# 11247     11.00       0.00         11.0               0.00  24.048799
# 11248     10.00       0.00         10.0               0.00  23.301759
# 11249   1415.00       0.00       1415.0               0.00  19.638472
# 11250   1210.00       0.00       1210.0               0.00  19.664859
# 11251      0.50       0.00          0.5               0.00  21.567599
#
#          longitud  altitud  cicloproductivo_Otoño-Invierno  \
# 0     -107.696760     12.0                               1
# 1     -116.595134     18.0                               0
# 2     -108.994343      9.0                               1
# 3     -107.393756     57.0                               1
# 4     -107.393756     57.0                               1
# ...           ...      ...                             ...
# 11247  -98.900294    149.0                               0
# 11248  -99.547539   1263.0                               1
# 11249  -97.103496   2420.0                               0
# 11250  -97.001371   1746.0                               0
# 11251  -88.232063     12.0                               1
#
#        cicloproductivo_Perennes  cicloproductivo_Primavera-Verano  ...  \
# 0                             0                                 0  ...
# 1                             0                                 1  ...
# 2                             0                                 0  ...
# 3                             0                                 0  ...
# 4                             0                                 0  ...
# ...                         ...                               ...  ...
# 11247                         0                                 1  ...
# 11248                         0                                 0  ...
# 11249                         0                                 1  ...
# 11250                         0                                 1  ...
# 11251                         0                                 0  ...
#
#        modalidad_Temporal  cultivo_Avena forrajera en verde  cultivo_Frijol  \
# 0                       0                                 0               0
# 1                       0                                 0               0
# 2                       0                                 0               0
# 3                       0                                 0               0
# 4                       0                                 0               0
# ...                   ...                               ...             ...
# 11247                   0                                 0               0
# 11248                   1                                 1               0
# 11249                   1                                 0               0
# 11250                   1                                 0               0
# 11251                   0                                 0               0
#
#        cultivo_Maíz grano  cultivo_Pastos y praderas  cultivo_Tomate rojo  \
# 0                       1                          0                    0
# 1                       0                          0                    1
# 2                       1                          0                    0
# 3                       1                          0                    0
# 4                       0                          0                    1
# ...                   ...                        ...                  ...
# 11247                   0                          0                    1
# 11248                   0                          0                    0
# 11249                   1                          0                    0
# 11250                   1                          0                    0
# 11251                   0                          0                    1
#
#        K=8 Cluster Labels  rendimiento                   cultivo  \
# 0                       7        11.45                Maíz grano
# 1                       4        83.58    Tomate rojo (jitomate)
# 2                       7        11.82                Maíz grano
# 3                       7        11.84                Maíz grano
# 4                       4        99.71    Tomate rojo (jitomate)
# ...                   ...          ...                       ...
# 11247                   4         0.00    Tomate rojo (jitomate)
# 11248                   0         0.00  Avena forrajera en verde
# 11249                   6         0.00                Maíz grano
# 11250                   6         0.00                Maíz grano
# 11251                   4         0.00    Tomate rojo (jitomate)
#
#                 estado
# 0              Sinaloa
# 1      Baja California
# 2              Sinaloa
# 3              Sinaloa
# 4              Sinaloa
# ...                ...
# 11247       Tamaulipas
# 11248       Tamaulipas
# 11249         Veracruz
# 11250         Veracruz
# 11251          Yucatán
#
# [11252 rows x 21 columns]

# %% [markdown]
# ## Connect to the database

# %%
from config import DATABASE_URI

# %%
# Import psycopg2 which is the PostgreSQL adapter for Python
# documentation https://www.psycopg.org/docs/install.html#install-from-source

# %%
#pip install psycopg2-binary

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
# create engine
engine = create_engine(DATABASE_URI)

# %%
# convert the dataframe into a sql table with pd.to_sql function
df.to_sql(con= engine, name='clustering', index=False, if_exists = "replace")
